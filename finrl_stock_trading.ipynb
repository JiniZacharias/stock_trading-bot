# %%
pip install --upgrade pip setuptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import configparser

parser = configparser.ConfigParser()

# %%
pip install --upgrade pip setuptools
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone https://github.com/AI4Finance-LLC/FinRL-Library.git
# Out:
# Cloning into 'FinRL-Library'...

# %%
# %cd FinRL-Library
# Out:
# c:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library\FinRL-Library

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ---------------------------------------- 3.0/3.0 MB 24.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------------------------------- 6.3/6.3 MB 48.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 46.1 MB/s eta 0:00:00
# ...

# %%
conda install -c conda-forge ta-lib
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - nvidia
#  - pytorch
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install TA_Lib‑0.4.0‑cp38‑cp38‑win_amd64.whl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'TA_Lib‑0.4.0‑cp38‑cp38‑win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: TA_Lib‑0.4.0‑cp38‑cp38‑win_amd64.whl is not a valid wheel filename.

# %%
# Solution 3: Building from Source
# Navigate to the extracted directory
# Navigate to the directory
# %cd FinRL-Library

# Run the install command
# !python setup.py install
# Out:
# [WinError 2] The system cannot find the file specified: 'FinRL-Library'
# c:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library\FinRL-Library
# running install
# running bdist_egg
# running egg_info
# creating FinRL.egg-info
# writing FinRL.egg-info\PKG-INFO
# writing dependency_links to FinRL.egg-info\dependency_links.txt
# writing top-level names to FinRL.egg-info\top_level.txt
# writing manifest file 'FinRL.egg-info\SOURCES.txt'
# reading manifest file 'FinRL.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'FinRL.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\lib\finrl
# copying finrl\config.py -> build\lib\finrl
# copying finrl\config_private.py -> build\lib\finrl
# copying finrl\config_tickers.py -> build\lib\finrl
# copying finrl\main.py -> build\lib\finrl
# copying finrl\plot.py -> build\lib\finrl
# copying finrl\test.py -> build\lib\finrl
# ...

# %%
pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Processing c:\users\aswin\onedrive\desktop\lstm+ddpg\finrl-library\finrl-library
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\aswin\appdata\local\temp\pip-install-jgr2ahmh\elegantrl_a9a8b3d1fcd6458897c70f66caa7aa49
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...

# %%
# !python -m build
# Out:
# c:\Users\aswin\anaconda3\envs\finrl_env\python.exe: No module named build.__main__; 'build' is a package and cannot be directly executed

# %%
# Install the build package
# !pip install build

# Navigate to the directory
# %cd C:/Users/aswin/OneDrive/Desktop/lstm+ddpg/FinRL-Library

# Run the build command
# !python -m build
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# C:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - poetry-core
# * Getting build dependencies for sdist...
# * Building sdist...
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - poetry-core
# * Getting build dependencies for wheel...
# * Building wheel...
# Successfully built finrl-0.3.8.tar.gz and finrl-0.3.8-py3-none-any.whl

# %%
import build
print("Build package imported successfully!")
# Out:
# Build package imported successfully!

# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

# %%
# %cd finrl/
# Out:
# C:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library\finrl

# %%
# Navigate to the finrl directory
# %cd C:/Users/aswin/OneDrive/Desktop/lstm+ddpg/FinRL-Library/finrl

# Adjust import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %matplotlib inline

from finrl.config import config
from finrl.preprocessor.yahoodownloader import YahooDownloader
from finrl.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.env.env_stocktrading import StockTradingEnv
from finrl.drl_agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint
import sys
sys.path.append("../FinRL-Library")
import itertools
# Out:
# C:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library\finrl
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 12
#       8 import datetime
#      10 get_ipython().run_line_magic('matplotlib', 'inline')
# ---> 12 from finrl.config import config
#      13 from finrl.preprocessor.yahoodownloader import YahooDownloader
#      14 from finrl.preprocessor.preprocessors import FeatureEngineer, data_split
#
# ImportError: cannot import name 'config' from 'finrl.config' (c:\Users\aswin\OneDrive\Desktop\lstm+ddpg\FinRL-Library\finrl\config.py)

# %%
# Your existing imports
from pprint import pprint
import sys
sys.path.append("../FinRL-Library")
import itertools

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)
